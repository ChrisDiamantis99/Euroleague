# %% [markdown]
# #### Import the necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import os

# %% [markdown]
# #### **Loading Data**

# %% [markdown]
# Loading all the information about the teams of Euroleague from 2016 to 2022

# %% [markdown]
# ##### Season 2016-2017

# %%
season_2016_2017 = pd.DataFrame(
    data = [ [1, 'Real Madrid', 23, 7, 10.312], [2, 'CSKA Moscow', 22, 8, 8.293], [3, 'Olympiacos', 19, 11, 9.360], [4, 'Panathinaikos', 19, 11, 11.172 ],
            [5, 'Fenerbahce', 18, 12, 11.219], [6, 'Anadolu Efes', 17, 13, 5.320], [7, 'Baskonia', 17, 13, 11.633 ], [8, 'Darussafaka', 16, 14, 4.677],
            [9, 'Crvena zvezda', 16, 14, 9.818], [10, 'Zalgiris', 14, 16, 11.418], [11, 'Barcelona', 12, 18, 4.931], [12, 'Galatasaray', 11, 19, 4.806],
            [13, 'Brose Bamberg', 10, 20, 6.415], [14, 'Maccabi Tel Aviv', 10, 20, 10.888], [15, 'UNICS', 8 ,22, 3.734],
            [16, 'Armani Milan', 8, 22, 9.483]] ,
    columns = ['Position', 'Team', 'Wins', 'Losses', 'Attendance']
    
)

season_2016_2017.insert(5, column= "Budget(In Millions)", value = [27, 35, 12, 14, 23, 18, 11.5, 20, 5, 8, 21, 12, 8, 11, 10, 19])
season_2016_2017.insert(6, column = "Country", value = ['Spain', 'Russia', 'Greece', 'Greece', 'Turkey', 'Turkey', 'Spain', 'Turkey', 'Serbia', 'Lithuania', 'Spain', 'Turkey', 'Germany', 'Israel', 'Russia', 'Italy'])

season_2016_2017['Arena'] = ' '
season_2016_2017['Capacity']  = ' '
for index, row in season_2016_2017.iterrows():
    team = row["Team"]
    if team == "Real Madrid":
        season_2016_2017.at[index, "Arena"] = "WiZink Center"
        season_2016_2017.at[index, "Capacity" ]= 15000
    elif team == "CSKA Moscow":
        season_2016_2017.at[index, "Arena"] = "Megasport Arena"
        season_2016_2017.at[index, "Capacity" ]= 13344
    elif team == "Olympiacos":
        season_2016_2017.at[index, "Arena"] = "Peace and Friendship Stadium"
        season_2016_2017.at[index, "Capacity" ]= 11640
    elif team == "Panathinaikos":
        season_2016_2017.at[index, "Arena"] = "OAKA"
        season_2016_2017.at[index, "Capacity" ]= 18989
    elif team == "Alba Berlin":
        season_2016_2017.at[index, "Arena"] = "Mercedes-Benz Arena"
        season_2016_2017.at[index, "Capacity" ]= 14500
    elif team == "Anadolu Efes":
        season_2016_2017.at[index, "Arena"] = "Sinan Erdem Dome"
        season_2016_2017.at[index, "Capacity" ]= 16000
    elif team == "Barcelona":
        season_2016_2017.at[index, "Arena"] = "Palau Blaugrana"
        season_2016_2017.at[index, "Capacity" ]= 7585
    elif team == "Baskonia":
        season_2016_2017.at[index, "Arena"] = "Buesa Arena"
        season_2016_2017.at[index, "Capacity" ]= 15504
    elif team == "Bayern Munich":
        season_2016_2017.at[index, "Arena"] = "Audi Dome"
        season_2016_2017.at[index, "Capacity" ]= 6700
    elif team == "Crvena zvezda":
        season_2016_2017.at[index, "Arena"] = "Stark Arena"
        season_2016_2017.at[index, "Capacity" ]= 13386
    elif team == "Fenerbahce":
        season_2016_2017.at[index, "Arena"] = "Ulker Sports and Event Hall"
        season_2016_2017.at[index, "Capacity" ]= 13059
    elif team == "ASVEL":
        season_2016_2017.at[index, "Arena"] = "Astroballe"
        season_2016_2017.at[index, "Capacity" ]= 5556
    elif team == "Maccabi Tel Aviv":
        season_2016_2017.at[index, "Arena"] = "Menora Mivtachim Arena"
        season_2016_2017.at[index, "Capacity" ]= 10383
    elif team == "Monaco":
        season_2016_2017.at[index, "Arena"] = "Salle Gaston Médecin"
        season_2016_2017.at[index, "Capacity" ]= 4090
    elif team == "UNICS":
        season_2016_2017.at[index, "Arena"] = "Basket-Hall Kazan"
        season_2016_2017.at[index, "Capacity" ]= 7482
    elif team == "Zalgiris":
        season_2016_2017.at[index, "Arena"] = "Zalgirio arena"
        season_2016_2017.at[index, "Capacity" ]= 15415
    elif team == "Zenit":
        season_2016_2017.at[index, "Arena"] = "Sibur Arena"
        season_2016_2017.at[index, "Capacity" ]= 7044
    elif team == "Darussafaka":
        season_2016_2017.at[index, "Arena"] = "Volkswagen Arena"
        season_2016_2017.at[index, "Capacity" ]= 5240
    elif team == "Armani Milan":
        season_2016_2017.at[index, "Arena"] = "Mediolanum Forum"
        season_2016_2017.at[index, "Capacity" ]= 12700
    elif team == "Galatasaray":
        season_2016_2017.at[index, "Arena"] = "Abdi Ipekci Arena"
        season_2016_2017.at[index, "Capacity" ]= 12270
    elif team == "Valencia":
        season_2016_2017.at[index, "Arena"] = "Fuente de San Luis"
        season_2016_2017.at[index, "Capacity" ]= 8500
    elif team == "Brose Bamberg":
        season_2016_2017.at[index, "Arena"] = "Brose Arena"
        season_2016_2017.at[index, "Capacity" ]= 6150
    elif team == "Unikaja Malaga":
        season_2016_2017.at[index, "Arena"] = "Martin Carpena"
        season_2016_2017.at[index, "Capacity" ]= 11300
    elif team == "Khimki":
        season_2016_2017.at[index, "Arena"] = "Mytishchi Arena"
        season_2016_2017.at[index, "Capacity" ]= 7280
    elif team == "Buducnost":
        season_2016_2017.at[index, "Arena"] = "Moraca Sports Center"
        season_2016_2017.at[index, "Capacity" ]= 5500
    elif team == "Gran Canaria":
        season_2016_2017.at[index, "Arena"] = "Gran Canaria Arena"
        season_2016_2017.at[index, "Capacity" ]= 11500

# %% [markdown]
# > Euroleague Standings 2016-2017

# %%
season_2016_2017
# Out:
#     Position              Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 0          1       Real Madrid    23       7      10.312                 27.0
# 1          2       CSKA Moscow    22       8       8.293                 35.0
# 2          3        Olympiacos    19      11       9.360                 12.0
# 3          4     Panathinaikos    19      11      11.172                 14.0
# 4          5        Fenerbahce    18      12      11.219                 23.0
# 5          6      Anadolu Efes    17      13       5.320                 18.0
# 6          7          Baskonia    17      13      11.633                 11.5
# 7          8       Darussafaka    16      14       4.677                 20.0
# 8          9     Crvena zvezda    16      14       9.818                  5.0
# 9         10          Zalgiris    14      16      11.418                  8.0
# 10        11         Barcelona    12      18       4.931                 21.0
# ...

# %% [markdown]
# ##### Season 2017-2018

# %%
s17_18 = season_2017_2018 = pd.DataFrame(
    data = [[1, 'CSKA Moscow', 24, 6, 8.211, 36, 'Russia'],    [2, 'Fenerbahce', 21, 9, 11.566, 30,'Turkey'],          [3, 'Olympiacos', 19, 11, 8.913, 15, 'Greece'], [4, 'Panathinaikos', 19, 11, 13.005, 15, 'Greece'],
            [5, 'Real Madrid', 19, 11, 10.030, 42, 'Spain'],   [6, 'Zalgiris', 18, 12, 13.560, 8.5, 'Lithuania'],     [7, 'Baskonia', 16, 14, 11.351, 16, 'Spain'],   [8, 'Khimki', 16, 14, 6.022, 24, 'Russia'],
            [9, 'Unikaja Malaga', 13, 17, 7.272, 15, 'Spain'], [10, 'Maccabi Tel Aviv', 13, 17, 10.731, 23, 'Israel'], [11, 'Valencia', 12, 18, 6.753, 10, 'Spain'],   [12, 'Brose Bamberg', 11, 19, 6.188, 11, 'Germany'],
            [13, 'Barcelona', 11, 19, 5.679, 36, 'Spain'],     [14, 'Crvena zvezda', 11, 19, 6.277, 5.8, 'Serbia'],    [15, 'Armani Milan', 10 ,20, 7.472, 25, 'Italy'],
            [16, 'Anadolu Efes', 7, 23, 3.900, 18, 'Turkey']],
    columns = ['Position', 'Team', 'Wins', 'Losses', 'Attendance', 'Budget(In Millions)', 'Country']
    
)

# %%
season_2017_2018['Arena'] = ' '
season_2017_2018['Capacity']  = ' '
for index, row in season_2017_2018.iterrows():
    team = row["Team"]
    if team == "Real Madrid":
        season_2017_2018.at[index, "Arena"] = "WiZink Center"
        season_2017_2018.at[index, "Capacity" ]= 15000
    elif team == "CSKA Moscow":
        season_2017_2018.at[index, "Arena"] = "Megasport Arena"
        season_2017_2018.at[index, "Capacity" ]= 13344
    elif team == "Olympiacos":
        season_2017_2018.at[index, "Arena"] = "Peace and Friendship Stadium"
        season_2017_2018.at[index, "Capacity" ]= 11640
    elif team == "Panathinaikos":
        season_2017_2018.at[index, "Arena"] = "OAKA"
        season_2017_2018.at[index, "Capacity" ]= 18989
    elif team == "Alba Berlin":
        season_2017_2018.at[index, "Arena"] = "Mercedes-Benz Arena"
        season_2017_2018.at[index, "Capacity" ]= 14500
    elif team == "Anadolu Efes":
        season_2017_2018.at[index, "Arena"] = "Sinan Erdem Dome"
        season_2017_2018.at[index, "Capacity" ]= 16000
    elif team == "Barcelona":
        season_2017_2018.at[index, "Arena"] = "Palau Blaugrana"
        season_2017_2018.at[index, "Capacity" ]= 7585
    elif team == "Baskonia":
        season_2017_2018.at[index, "Arena"] = "Buesa Arena"
        season_2017_2018.at[index, "Capacity" ]= 15504
    elif team == "Bayern Munich":
        season_2017_2018.at[index, "Arena"] = "Audi Dome"
        season_2017_2018.at[index, "Capacity" ]= 6700
    elif team == "Crvena zvezda":
        season_2017_2018.at[index, "Arena"] = "Stark Arena"
        season_2017_2018.at[index, "Capacity" ]= 13386
    elif team == "Fenerbahce":
        season_2017_2018.at[index, "Arena"] = "Ulker Sports and Event Hall"
        season_2017_2018.at[index, "Capacity" ]= 13059
    elif team == "ASVEL":
        season_2017_2018.at[index, "Arena"] = "Astroballe"
        season_2017_2018.at[index, "Capacity" ]= 5556
    elif team == "Maccabi Tel Aviv":
        season_2017_2018.at[index, "Arena"] = "Menora Mivtachim Arena"
        season_2017_2018.at[index, "Capacity" ]= 10383
    elif team == "Monaco":
        season_2017_2018.at[index, "Arena"] = "Salle Gaston Médecin"
        season_2017_2018.at[index, "Capacity" ]= 4090
    elif team == "UNICS":
        season_2017_2018.at[index, "Arena"] = "Basket-Hall Kazan"
        season_2017_2018.at[index, "Capacity" ]= 7482
    elif team == "Zalgiris":
        season_2017_2018.at[index, "Arena"] = "Zalgirio arena"
        season_2017_2018.at[index, "Capacity" ]= 15415
    elif team == "Zenit":
        season_2017_2018.at[index, "Arena"] = "Sibur Arena"
        season_2017_2018.at[index, "Capacity" ]= 7044
    elif team == "Darussafaka":
        season_2017_2018.at[index, "Arena"] = "Volkswagen Arena"
        season_2017_2018.at[index, "Capacity" ]= 5240
    elif team == "Armani Milan":
        season_2017_2018.at[index, "Arena"] = "Mediolanum Forum"
        season_2017_2018.at[index, "Capacity" ]= 12700
    elif team == "Galatasaray":
        season_2017_2018.at[index, "Arena"] = "Abdi Ipekci Arena"
        season_2017_2018.at[index, "Capacity" ]= 12270
    elif team == "Valencia":
        season_2017_2018.at[index, "Arena"] = "Fuente de San Luis"
        season_2017_2018.at[index, "Capacity" ]= 8500
    elif team == "Brose Bamberg":
        season_2017_2018.at[index, "Arena"] = "Brose Arena"
        season_2017_2018.at[index, "Capacity" ]= 6150
    elif team == "Unikaja Malaga":
        season_2017_2018.at[index, "Arena"] = "Martin Carpena"
        season_2017_2018.at[index, "Capacity" ]= 11300
    elif team == "Khimki":
        season_2017_2018.at[index, "Arena"] = "Mytishchi Arena"
        season_2017_2018.at[index, "Capacity" ]= 7280
    elif team == "Buducnost":
        season_2017_2018.at[index, "Arena"] = "Moraca Sports Center"
        season_2017_2018.at[index, "Capacity" ]= 5500
    elif team == "Gran Canaria":
        season_2017_2018.at[index, "Arena"] = "Gran Canaria Arena"
        season_2017_2018.at[index, "Capacity" ]= 11500

# %% [markdown]
# > Euroleague Standings 2017-2018

# %%
season_2017_2018
# Out:
#     Position              Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 0          1       CSKA Moscow    24       6       8.211                 36.0
# 1          2        Fenerbahce    21       9      11.566                 30.0
# 2          3        Olympiacos    19      11       8.913                 15.0
# 3          4     Panathinaikos    19      11      13.005                 15.0
# 4          5       Real Madrid    19      11      10.030                 42.0
# 5          6          Zalgiris    18      12      13.560                  8.5
# 6          7          Baskonia    16      14      11.351                 16.0
# 7          8            Khimki    16      14       6.022                 24.0
# 8          9    Unikaja Malaga    13      17       7.272                 15.0
# 9         10  Maccabi Tel Aviv    13      17      10.731                 23.0
# 10        11          Valencia    12      18       6.753                 10.0
# ...

# %% [markdown]
# ##### Season 2018-2019

# %%
s18_19 = season_2018_2019 = pd.DataFrame(
    data = [[1, 'Fenerbahce', 25, 5, 11.566, 30, 'Turkey'],      [2, 'CSKA Moscow', 24, 6, 8.211, 36, 'Russia'],              [3, 'Real Madrid', 22, 8, 10.030, 42, 'Spain'],       [4, 'Anadolu Efes', 20, 10, 3.900, 26, 'Turkey'],
            [5, 'Barcelona', 18, 12, 5.679, 37.3, 'Spain'],      [6,'Panathinaikos', 16, 14, 13.005, 15, 'Greece'],           [7, 'Baskonia', 15, 15, 11.351, 17, 'Spain'],          [8, 'Zalgiris', 15, 15, 13.560, 10.7, 'Lithuania'],
            [9, 'Olympiacos', 15, 15, 8.913, 15, 'Greece'],      [10, 'Maccabi Tel Aviv', 14, 16, 10.731, 25, 'Israel'],      [11, 'Bayern Munich', 14, 16, 6.753, 12, 'Germany'],   [12, 'Armani Milan', 14 ,16, 7.472, 25, 'Italy'],
            [13, 'Khimki', 9, 21, 6.022, 33.3, 'Russia'],        [14, 'Gran Canaria', 8, 22, 6.277, 10, 'Spain'],             [15, 'Buducnost', 6 ,24, 7.472, 5.8, 'Montenegro'],
            [16, 'Darussafaka', 5, 25, 3.900, 6, 'Turkey']],
    columns = ['Position', 'Team', 'Wins', 'Losses', 'Attendance', 'Budget(In Millions)', 'Country']
)

season_2018_2019['Arena'] = ' '
season_2018_2019['Capacity']  = ' '
for index, row in season_2018_2019.iterrows():
    team = row["Team"]
    if team == "Real Madrid":
        season_2018_2019.at[index, "Arena"] = "WiZink Center"
        season_2018_2019.at[index, "Capacity" ]= 15000
    elif team == "CSKA Moscow":
        season_2018_2019.at[index, "Arena"] = "Megasport Arena"
        season_2018_2019.at[index, "Capacity" ]= 13344
    elif team == "Olympiacos":
        season_2018_2019.at[index, "Arena"] = "Peace and Friendship Stadium"
        season_2018_2019.at[index, "Capacity" ]= 11640
    elif team == "Panathinaikos":
        season_2018_2019.at[index, "Arena"] = "OAKA"
        season_2018_2019.at[index, "Capacity" ]= 18989
    elif team == "Alba Berlin":
        season_2018_2019.at[index, "Arena"] = "Mercedes-Benz Arena"
        season_2018_2019.at[index, "Capacity" ]= 14500
    elif team == "Anadolu Efes":
        season_2018_2019.at[index, "Arena"] = "Sinan Erdem Dome"
        season_2018_2019.at[index, "Capacity" ]= 16000
    elif team == "Barcelona":
        season_2018_2019.at[index, "Arena"] = "Palau Blaugrana"
        season_2018_2019.at[index, "Capacity" ]= 7585
    elif team == "Baskonia":
        season_2018_2019.at[index, "Arena"] = "Buesa Arena"
        season_2018_2019.at[index, "Capacity" ]= 15504
    elif team == "Bayern Munich":
        season_2018_2019.at[index, "Arena"] = "Audi Dome"
        season_2018_2019.at[index, "Capacity" ]= 6700
    elif team == "Crvena zvezda":
        season_2018_2019.at[index, "Arena"] = "Stark Arena"
        season_2018_2019.at[index, "Capacity" ]= 13386
    elif team == "Fenerbahce":
        season_2018_2019.at[index, "Arena"] = "Ulker Sports and Event Hall"
        season_2018_2019.at[index, "Capacity" ]= 13059
    elif team == "ASVEL":
        season_2018_2019.at[index, "Arena"] = "Astroballe"
        season_2018_2019.at[index, "Capacity" ]= 5556
    elif team == "Maccabi Tel Aviv":
        season_2018_2019.at[index, "Arena"] = "Menora Mivtachim Arena"
        season_2018_2019.at[index, "Capacity" ]= 10383
    elif team == "Monaco":
        season_2018_2019.at[index, "Arena"] = "Salle Gaston Médecin"
        season_2018_2019.at[index, "Capacity" ]= 4090
    elif team == "UNICS":
        season_2018_2019.at[index, "Arena"] = "Basket-Hall Kazan"
        season_2018_2019.at[index, "Capacity" ]= 7482
    elif team == "Zalgiris":
        season_2018_2019.at[index, "Arena"] = "Zalgirio arena"
        season_2018_2019.at[index, "Capacity" ]= 15415
    elif team == "Zenit":
        season_2018_2019.at[index, "Arena"] = "Sibur Arena"
        season_2018_2019.at[index, "Capacity" ]= 7044
    elif team == "Darussafaka":
        season_2018_2019.at[index, "Arena"] = "Volkswagen Arena"
        season_2018_2019.at[index, "Capacity" ]= 5240
    elif team == "Armani Milan":
        season_2018_2019.at[index, "Arena"] = "Mediolanum Forum"
        season_2018_2019.at[index, "Capacity" ]= 12700
    elif team == "Galatasaray":
        season_2018_2019.at[index, "Arena"] = "Abdi Ipekci Arena"
        season_2018_2019.at[index, "Capacity" ]= 12270
    elif team == "Valencia":
        season_2018_2019.at[index, "Arena"] = "Fuente de San Luis"
        season_2018_2019.at[index, "Capacity" ]= 8500
    elif team == "Brose Bamberg":
        season_2018_2019.at[index, "Arena"] = "Brose Arena"
        season_2018_2019.at[index, "Capacity" ]= 6150
    elif team == "Unikaja Malaga":
        season_2018_2019.at[index, "Arena"] = "Martin Carpena"
        season_2018_2019.at[index, "Capacity" ]= 11300
    elif team == "Khimki":
        season_2018_2019.at[index, "Arena"] = "Mytishchi Arena"
        season_2018_2019.at[index, "Capacity" ]= 7280
    elif team == "Buducnost":
        season_2018_2019.at[index, "Arena"] = "Moraca Sports Center"
        season_2018_2019.at[index, "Capacity" ]= 5500
    elif team == "Gran Canaria":
        season_2018_2019.at[index, "Arena"] = "Gran Canaria Arena"
        season_2018_2019.at[index, "Capacity" ]= 11500

# %% [markdown]
# > Euroleague Standings 2018-2019

# %%
season_2018_2019
# Out:
#     Position              Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 0          1        Fenerbahce    25       5      11.566                 30.0
# 1          2       CSKA Moscow    24       6       8.211                 36.0
# 2          3       Real Madrid    22       8      10.030                 42.0
# 3          4      Anadolu Efes    20      10       3.900                 26.0
# 4          5         Barcelona    18      12       5.679                 37.3
# 5          6     Panathinaikos    16      14      13.005                 15.0
# 6          7          Baskonia    15      15      11.351                 17.0
# 7          8          Zalgiris    15      15      13.560                 10.7
# 8          9        Olympiacos    15      15       8.913                 15.0
# 9         10  Maccabi Tel Aviv    14      16      10.731                 25.0
# 10        11     Bayern Munich    14      16       6.753                 12.0
# ...

# %% [markdown]
# ##### Season 2019-2020

# %% [markdown]
# >The season 2019-2020 was postponed due to COVID-19 Pandemic

# %%
s19_20 = season_2019_2020 = pd.DataFrame(
    data = [[1, 'Anadolu Efes', 24, 4, 13.113, 26.5, 'Turkey'],    [2, 'Real Madrid', 22, 6, 9.649, 44.1, 'Spain'],       [3, 'Barcelona', 22, 6, 5.977, 45.2, 'Spain'],     [4, 'CSKA Moscow', 19, 9, 7.050, 44.9, 'Russia'],
            [5, 'Maccabi Tel Aviv', 19, 9, 10.038, 25, 'Israel'],  [6,'Panathinaikos', 14, 14, 9.858, 15.4, 'Greece'],    [7, 'Khimki', 13, 15, 5.189, 36.7, 'Russia'],      [8, 'Fenerbahce', 13, 15, 11.566, 33.1, 'Turkey'],
            [9, 'Zalgiris', 12, 16, 14.221, 13.1, 'Lithuania'],    [10, 'Valencia', 12, 16, 7.433, 10, 'Spain'],          [11, 'Olympiacos', 12, 16, 7.287, 17.6, 'Greece'], [12, 'Armani Milan', 12, 16, 8.491, 34.2, 'Italy'],
            [13, 'Baskonia', 15, 15, 10.661, 17.6, 'Spain'],       [14,  'Crvena zvezda', 11, 19, 11.744, 9.2, 'Serbia'], [15, 'ASVEL', 10, 18, 5.326, 12.7, 'France'],      [16, 'ALBA Berlin', 9, 19, 9.930, 12.1, 'Germany'],
            [17, 'Bayern Munich', 8, 20, 4.688, 25.3, 'Germany'],  [18, 'Zenit', 8, 20, 4.299, 29.4, 'Russia']],
    columns = ['Position', 'Team', 'Wins', 'Losses', 'Attendance', 'Budget(In Millions)', 'Country']
)


season_2019_2020['Arena'] = ' '
season_2019_2020['Capacity']  = ' '
for index, row in season_2019_2020.iterrows():
    team = row["Team"]
    if team == "Real Madrid":
        season_2019_2020.at[index, "Arena"] = "WiZink Center"
        season_2019_2020.at[index, "Capacity" ]= 15000
    elif team == "CSKA Moscow":
        season_2019_2020.at[index, "Arena"] = "Megasport Arena"
        season_2019_2020.at[index, "Capacity" ]= 13344
    elif team == "Olympiacos":
        season_2019_2020.at[index, "Arena"] = "Peace and Friendship Stadium"
        season_2019_2020.at[index, "Capacity" ]= 11640
    elif team == "Panathinaikos":
        season_2019_2020.at[index, "Arena"] = "OAKA"
        season_2019_2020.at[index, "Capacity" ]= 18989
    elif team == "ALBA Berlin":
        season_2019_2020.at[index, "Arena"] = "Mercedes-Benz Arena"
        season_2019_2020.at[index, "Capacity" ]= 14500
    elif team == "Anadolu Efes":
        season_2019_2020.at[index, "Arena"] = "Sinan Erdem Dome"
        season_2019_2020.at[index, "Capacity" ]= 16000
    elif team == "Barcelona":
        season_2019_2020.at[index, "Arena"] = "Palau Blaugrana"
        season_2019_2020.at[index, "Capacity" ]= 7585
    elif team == "Baskonia":
        season_2019_2020.at[index, "Arena"] = "Buesa Arena"
        season_2019_2020.at[index, "Capacity" ]= 15504
    elif team == "Bayern Munich":
        season_2019_2020.at[index, "Arena"] = "Audi Dome"
        season_2019_2020.at[index, "Capacity" ]= 6700
    elif team == "Crvena zvezda":
        season_2019_2020.at[index, "Arena"] = "Stark Arena"
        season_2019_2020.at[index, "Capacity" ]= 13386
    elif team == "Fenerbahce":
        season_2019_2020.at[index, "Arena"] = "Ulker Sports and Event Hall"
        season_2019_2020.at[index, "Capacity" ]= 13059
    elif team == "ASVEL":
        season_2019_2020.at[index, "Arena"] = "Astroballe"
        season_2019_2020.at[index, "Capacity" ]= 5556
    elif team == "Maccabi Tel Aviv":
        season_2019_2020.at[index, "Arena"] = "Menora Mivtachim Arena"
        season_2019_2020.at[index, "Capacity" ]= 10383
    elif team == "Monaco":
        season_2019_2020.at[index, "Arena"] = "Salle Gaston Médecin"
        season_2019_2020.at[index, "Capacity" ]= 4090
    elif team == "UNICS":
        season_2019_2020.at[index, "Arena"] = "Basket-Hall Kazan"
        season_2019_2020.at[index, "Capacity" ]= 7482
    elif team == "Zalgiris":
        season_2019_2020.at[index, "Arena"] = "Zalgirio arena"
        season_2019_2020.at[index, "Capacity" ]= 15415
    elif team == "Zenit":
        season_2019_2020.at[index, "Arena"] = "Sibur Arena"
        season_2019_2020.at[index, "Capacity" ]= 7044
    elif team == "Darussafaka":
        season_2019_2020.at[index, "Arena"] = "Volkswagen Arena"
        season_2019_2020.at[index, "Capacity" ]= 5240
    elif team == "Armani Milan":
        season_2019_2020.at[index, "Arena"] = "Mediolanum Forum"
        season_2019_2020.at[index, "Capacity" ]= 12700
    elif team == "Galatasaray":
        season_2019_2020.at[index, "Arena"] = "Abdi Ipekci Arena"
        season_2019_2020.at[index, "Capacity" ]= 12270
    elif team == "Valencia":
        season_2019_2020.at[index, "Arena"] = "Fuente de San Luis"
        season_2019_2020.at[index, "Capacity" ]= 8500
    elif team == "Brose Bamberg":
        season_2019_2020.at[index, "Arena"] = "Brose Arena"
        season_2019_2020.at[index, "Capacity" ]= 6150
    elif team == "Unikaja Malaga":
        season_2019_2020.at[index, "Arena"] = "Martin Carpena"
        season_2019_2020.at[index, "Capacity" ]= 11300
    elif team == "Khimki":
        season_2019_2020.at[index, "Arena"] = "Mytishchi Arena"
        season_2019_2020.at[index, "Capacity" ]= 7280
    elif team == "Buducnost":
        season_2019_2020.at[index, "Arena"] = "Moraca Sports Center"
        season_2019_2020.at[index, "Capacity" ]= 5500
    elif team == "Gran Canaria":
        season_2019_2020.at[index, "Arena"] = "Gran Canaria Arena"
        season_2019_2020.at[index, "Capacity" ]= 11500

# %% [markdown]
# > Euroleague Standings 2019-2020

# %%
s19_20
# Out:
#     Position              Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 0          1      Anadolu Efes    24       4      13.113                 26.5
# 1          2       Real Madrid    22       6       9.649                 44.1
# 2          3         Barcelona    22       6       5.977                 45.2
# 3          4       CSKA Moscow    19       9       7.050                 44.9
# 4          5  Maccabi Tel Aviv    19       9      10.038                 25.0
# 5          6     Panathinaikos    14      14       9.858                 15.4
# 6          7            Khimki    13      15       5.189                 36.7
# 7          8        Fenerbahce    13      15      11.566                 33.1
# 8          9          Zalgiris    12      16      14.221                 13.1
# 9         10          Valencia    12      16       7.433                 10.0
# 10        11        Olympiacos    12      16       7.287                 17.6
# ...

# %% [markdown]
# ##### Season 2020-2021(Covid)

# %% [markdown]
# >Only seven teams played basketball with spectators. Between 100 and 7,500 socially-distanced fans, depending on the venue and country, were allowed into the arenas of CSKA, Zenit, Fenerbahçe, Khimki, Maccabi, Žalgiris, Valencia, Milan, Baskonia, ASVEL, ALBA and Crvena zvezda

# %%
s20_21 = season_2020_2021 = pd.DataFrame(
    data = [[1,'Barcelona', 24, 10, 0, 23, 'Spain'],               [2, 'CSKA Moscow', 24, 10, 3419, 25, 'Russia'], [3, 'Anadolu Efes', 22, 12, 0, 23, 'Turkey'],      [4, 'Armani Milan', 21, 13, 809, 25, 'Italy'],
            [5, 'Bayern Munich', 21, 13, 0, 6, 'Germany'],         [6,'Real Madrid', 20, 14, 0, 23, 'Spain'],       [7, 'Fenerbahce', 20, 14, 268, 19, 'Turkey'],      [8, 'Zenit', 20, 14, 2775, 17, 'Russia'],
            [9, 'Valencia', 19, 15, 393, 13, 'Spain'],             [10, 'Baskonia', 18, 16, 500, 10, 'Spain'],      [11,  'Zalgiris', 17, 17, 3460, 8, 'Lithuania'],  [12, 'Olympiacos', 16, 18, 0, 9, 'Greece'],
            [13, 'Maccabi Tel Aviv', 14, 20, 1767, 14, 'Israel'], [14,  'ASVEL', 13, 21, 970, 7, 'France'],        [15, 'ALBA Berlin', 12, 22, 599, 12.1, 'Germany'], [16, 'Panathinaikos', 11, 23, 0, 6, 'Greece'],
            [17, 'Crvena zvezda', 10, 24, 183, 10, 'Serbia'],      [18, 'Khimki', 4, 30, 785, 20, 'Russia']],
    columns = ['Position', 'Team', 'Wins', 'Losses', 'Attendance', 'Budget(In Millions)', 'Country']
)

# %% [markdown]
# > Euroleague Standings 2020-2021

# %%
s20_21
# Out:
#     Position              Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 0          1         Barcelona    24      10           0                 23.0
# 1          2       CSKA Moscow    24      10        3419                 25.0
# 2          3      Anadolu Efes    22      12           0                 23.0
# 3          4      Armani Milan    21      13         809                 25.0
# 4          5     Bayern Munich    21      13           0                  6.0
# 5          6       Real Madrid    20      14           0                 23.0
# 6          7        Fenerbahce    20      14         268                 19.0
# 7          8             Zenit    20      14        2775                 17.0
# 8          9          Valencia    19      15         393                 13.0
# 9         10          Baskonia    18      16         500                 10.0
# 10        11          Zalgiris    17      17        3460                  8.0
# ...

# %% [markdown]
# ##### Season 2021-2022

# %%
s21_22 = season_2021_2022 = pd.DataFrame(
    data = [[1,'Barcelona', 21, 7, 5174, 43.5, 'Spain'],         [2, 'Olympiacos', 19, 9, 7037, 15, 'Greece'],     [3, 'Armani Milan', 19, 9, 4893, 30, 'Italy'],       [4, 'Real Madrid', 18, 10, 5943, 44, 'Spain'],
            [5, 'Maccabi Tel Aviv', 17, 11, 8429, 18, 'Israel'], [6, 'Anadolu Efes', 16, 12, 11876, 25, 'Turkey'], [7, 'Monaco', 15, 13, 3536, 14.7, 'France'],         [8, 'Bayern Munich', 14, 14, 2673, 21, 'Germany'],
            [9, 'Baskonia', 12, 16, 6885, 10, 'Spain'],          [10, 'ALBA Berlin', 12, 16, 3825, 11, 'Germany'], [11,  'Crvena zvezda', 12, 16, 6042, 8.4, 'Serbia'], [12, 'Fenerbahce', 10, 18, 5545, 24, 'Turkey'],
            [13, 'Panathinaikos', 9, 19, 3883, 9.5, 'Greece'],   [14,  'ASVEL', 8, 20, 4237, 15.1, 'France'],      [15, 'Zalgiris', 8, 20, 7630, 10, 'Lithuania'],      [16, 'Zenit', 0, 0, 0, 23, 'Russia'],
            [17, 'CSKA Moscow', 0, 0, 0, 33, 'Russia'],           [18, 'UNICS', 0, 0, 0, 15, 'Russia']],
    columns = ['Position', 'Team', 'Wins', 'Losses', 'Attendance', 'Budget(In Millions)', 'Country']
)



season_2021_2022['Arena'] = ' '
season_2021_2022['Capacity']  = ' '
for index, row in season_2021_2022.iterrows():
    team = row["Team"]
    if team == "Real Madrid":
        season_2021_2022.at[index, "Arena"] = "WiZink Center"
        season_2021_2022.at[index, "Capacity" ]= 15000
    elif team == "CSKA Moscow":
        season_2021_2022.at[index, "Arena"] = "Megasport Arena"
        season_2021_2022.at[index, "Capacity" ]= 13344
    elif team == "Olympiacos":
        season_2021_2022.at[index, "Arena"] = "Peace and Friendship Stadium"
        season_2021_2022.at[index, "Capacity" ]= 11640
    elif team == "Panathinaikos":
        season_2021_2022.at[index, "Arena"] = "OAKA"
        season_2021_2022.at[index, "Capacity" ]= 18989
    elif team == "ALBA Berlin":
        season_2021_2022.at[index, "Arena"] = "Mercedes-Benz Arena"
        season_2021_2022.at[index, "Capacity" ]= 14500
    elif team == "Anadolu Efes":
        season_2021_2022.at[index, "Arena"] = "Sinan Erdem Dome"
        season_2021_2022.at[index, "Capacity" ]= 16000
    elif team == "Barcelona":
        season_2021_2022.at[index, "Arena"] = "Palau Blaugrana"
        season_2021_2022.at[index, "Capacity" ]= 7585
    elif team == "Baskonia":
        season_2021_2022.at[index, "Arena"] = "Buesa Arena"
        season_2021_2022.at[index, "Capacity" ]= 15504
    elif team == "Bayern Munich":
        season_2021_2022.at[index, "Arena"] = "Audi Dome"
        season_2021_2022.at[index, "Capacity" ]= 6700
    elif team == "Crvena zvezda":
        season_2021_2022.at[index, "Arena"] = "Stark Arena"
        season_2021_2022.at[index, "Capacity" ]= 13386
    elif team == "Fenerbahce":
        season_2021_2022.at[index, "Arena"] = "Ulker Sports and Event Hall"
        season_2021_2022.at[index, "Capacity" ]= 13059
    elif team == "ASVEL":
        season_2021_2022.at[index, "Arena"] = "Astroballe"
        season_2021_2022.at[index, "Capacity" ]= 5556
    elif team == "Maccabi Tel Aviv":
        season_2021_2022.at[index, "Arena"] = "Menora Mivtachim Arena"
        season_2021_2022.at[index, "Capacity" ]= 10383
    elif team == "Monaco":
        season_2021_2022.at[index, "Arena"] = "Salle Gaston Médecin"
        season_2021_2022.at[index, "Capacity" ]= 4090
    elif team == "UNICS":
        season_2021_2022.at[index, "Arena"] = "Basket-Hall Kazan"
        season_2021_2022.at[index, "Capacity" ]= 7482
    elif team == "Zalgiris":
        season_2021_2022.at[index, "Arena"] = "Zalgirio arena"
        season_2021_2022.at[index, "Capacity" ]= 15415
    elif team == "Zenit":
        season_2021_2022.at[index, "Arena"] = "Sibur Arena"
        season_2021_2022.at[index, "Capacity" ]= 7044
    elif team == "Darussafaka":
        season_2021_2022.at[index, "Arena"] = "Volkswagen Arena"
        season_2021_2022.at[index, "Capacity" ]= 5240
    elif team == "Armani Milan":
        season_2021_2022.at[index, "Arena"] = "Mediolanum Forum"
        season_2021_2022.at[index, "Capacity" ]= 12700
    elif team == "Galatasaray":
        season_2021_2022.at[index, "Arena"] = "Abdi Ipekci Arena"
        season_2021_2022.at[index, "Capacity" ]= 12270
    elif team == "Valencia":
        season_2021_2022.at[index, "Arena"] = "Fuente de San Luis"
        season_2021_2022.at[index, "Capacity" ]= 8500
    elif team == "Brose Bamberg":
        season_2021_2022.at[index, "Arena"] = "Brose Arena"
        season_2021_2022.at[index, "Capacity" ]= 6150
    elif team == "Unikaja Malaga":
        season_2021_2022.at[index, "Arena"] = "Martin Carpena"
        season_2021_2022.at[index, "Capacity" ]= 11300
    elif team == "Khimki":
        season_2021_2022.at[index, "Arena"] = "Mytishchi Arena"
        season_2021_2022.at[index, "Capacity" ]= 7280
    elif team == "Buducnost":
        season_2021_2022.at[index, "Arena"] = "Moraca Sports Center"
        season_2021_2022.at[index, "Capacity" ]= 5500
    elif team == "Gran Canaria":
        season_2021_2022.at[index, "Arena"] = "Gran Canaria Arena"
        season_2021_2022.at[index, "Capacity" ]= 11500

# %% [markdown]
# > Euroleague Standings 2021-2022

# %%
s21_22
# Out:
#     Position              Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 0          1         Barcelona    21       7        5174                 43.5
# 1          2        Olympiacos    19       9        7037                 15.0
# 2          3      Armani Milan    19       9        4893                 30.0
# 3          4       Real Madrid    18      10        5943                 44.0
# 4          5  Maccabi Tel Aviv    17      11        8429                 18.0
# 5          6      Anadolu Efes    16      12       11876                 25.0
# 6          7            Monaco    15      13        3536                 14.7
# 7          8     Bayern Munich    14      14        2673                 21.0
# 8          9          Baskonia    12      16        6885                 10.0
# 9         10       ALBA Berlin    12      16        3825                 11.0
# 10        11     Crvena zvezda    12      16        6042                  8.4
# ...

# %% [markdown]
# #### **Season 2016-2017** *Analyze & Filter*

# %% [markdown]
# *Informations & Fun Facts*

# %% [markdown]
# >The max attendance of a team is 11.633

# %%
max_att = season_2016_2017['Attendance'].max()
max_att
# Out:
# 11.633

# %% [markdown]
# >The team with max attendance is Baskonia

# %%
season_2016_2017.loc[season_2016_2017['Attendance'] == max_att, ['Team']]
# Out:
#        Team
# 6  Baskonia

# %% [markdown]
# >The min attendance of a team is 3.734

# %%
min_att = season_2016_2017['Attendance'].min()
min_att
# Out:
# 3.734

# %% [markdown]
# >The team with min attendance was UNICS

# %%
season_2016_2017.loc[season_2016_2017['Attendance'] == min_att, ['Team']]
# Out:
#      Team
# 14  UNICS

# %% [markdown]
# >The teams that qualified in Euroleague Playoffs 2016-2017 are

# %%
season_2016_2017.loc[season_2016_2017['Position'] <= 8, ['Team', 'Wins', 'Losses'] ]
# Out:
#             Team  Wins  Losses
# 0    Real Madrid    23       7
# 1    CSKA Moscow    22       8
# 2     Olympiacos    19      11
# 3  Panathinaikos    19      11
# 4     Fenerbahce    18      12
# 5   Anadolu Efes    17      13
# 6       Baskonia    17      13
# 7    Darussafaka    16      14

# %%
season_2017_2018.iloc[lambda x: x.index == 3]
# Out:
#    Position           Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 3         4  Panathinaikos    19      11      13.005                 15.0
#
#   Country Arena Capacity
# 3  Greece  OAKA    18989

# %%
sum_countries_2016_2017 = season_2017_2018['Country'].value_counts()

# %%
sum_countries_2016_2017
# Out:
# Spain        5
# Russia       2
# Turkey       2
# Greece       2
# Lithuania    1
# Israel       1
# Germany      1
# Serbia       1
# Italy        1
# Name: Country, dtype: int64

# %% [markdown]
# ~*Visualization*~

# %% [markdown]
# >How many teams every country represent in Euroleague

# %%
country_labels = ['Spain', 'Russia', 'Turkey', 'Greece', 'Lithuania', 'Israel', 'Germany', 'Serbia', 'Italy']
myexplode = [0.2, 0, 0, 0, 0.1, 0.2, 0.3, 0, 0]
plt.pie(sum_countries_2016_2017, labels = country_labels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# #### **Season 2021-2022** *Analyze & Filter*

# %% [markdown]
# *We will focus more in Season 2021-2022*

# %% [markdown]
# >Due to the invasion of Russia in Ukraine the Euroleague banned Russian teams

# %%
season_2021_2022 = season_2021_2022.drop([15,16,17], axis = 0)

# %% [markdown]
# > Add a column **Playoffs** that shows if a team is qualified at playoffs or not.

# %%
def playoffs_enter(row):
    if row['Position'] <= 8:
        return 'Yes'
    else:
        return'No'

# %%
season_2021_2022['Playoffs'] = season_2021_2022.apply(playoffs_enter, axis = 1)

# %% [markdown]
# >The new format of Euroleague Standings looks like this:

# %%
season_2021_2022
# Out:
#     Position              Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 0          1         Barcelona    21       7        5174                 43.5
# 1          2        Olympiacos    19       9        7037                 15.0
# 2          3      Armani Milan    19       9        4893                 30.0
# 3          4       Real Madrid    18      10        5943                 44.0
# 4          5  Maccabi Tel Aviv    17      11        8429                 18.0
# 5          6      Anadolu Efes    16      12       11876                 25.0
# 6          7            Monaco    15      13        3536                 14.7
# 7          8     Bayern Munich    14      14        2673                 21.0
# 8          9          Baskonia    12      16        6885                 10.0
# 9         10       ALBA Berlin    12      16        3825                 11.0
# 10        11     Crvena zvezda    12      16        6042                  8.4
# ...

# %% [markdown]
# > **Win Rate**

# %% [markdown]
# Calculating Win Rate(%) for every team

# %%
win_rate = season_2021_2022["Wins"] / 28 #total games that every team played
percentage = np.round(win_rate * 100, 2)
season_2021_2022.insert(loc = 9, column = "Win_Rate", value = percentage)

# %%
max_rate = season_2021_2022['Win_Rate'].max()
min_rate = season_2021_2022['Win_Rate'].min()

# %% [markdown]
# - The team with the highest win percentage is **Barcelona** with **75%**.

# %%
print("Max Rate: {}%".format(max_rate))
# Out:
# Max Rate: 75.0%

# %%
season_2021_2022.loc[season_2021_2022['Win_Rate'] == max_rate, ['Team']]
# Out:
#         Team
# 0  Barcelona

# %% [markdown]
# - The team with the lowest win percentage are both **Asvel** and **Zalgirs** with **28.57%**.

# %%
print("Min Rate: {}%".format(min_rate))
# Out:
# Min Rate: 28.57%

# %%
season_2021_2022.loc[season_2021_2022['Win_Rate'] == min_rate, ['Team']]
# Out:
#         Team
# 13     ASVEL
# 14  Zalgiris

# %% [markdown]
# - Total attendance every team had in their arenas

# %%
total_attendance = season_2021_2022["Attendance"] * 14 #total games every team have played in their arenas 
season_2021_2022.insert(loc = 10, column = "Total Attendance", value = total_attendance)

# %%
season_2021_2022[["Team", "Total Attendance"]]
# Out:
#                 Team  Total Attendance
# 0          Barcelona             72436
# 1         Olympiacos             98518
# 2       Armani Milan             68502
# 3        Real Madrid             83202
# 4   Maccabi Tel Aviv            118006
# 5       Anadolu Efes            166264
# 6             Monaco             49504
# 7      Bayern Munich             37422
# 8           Baskonia             96390
# 9        ALBA Berlin             53550
# 10     Crvena zvezda             84588
# 11        Fenerbahce             77630
# 12     Panathinaikos             54362
# 13             ASVEL             59318
# 14          Zalgiris            106820

# %% [markdown]
# > Percentage(%) of arenas capacity

# %%
perc_arenas = season_2021_2022["Attendance"] / season_2021_2022["Capacity"]
sum_arenas = perc_arenas * 100
percentage_arenas = np.around(sum_arenas.astype(np.double), 2)
season_2021_2022.insert(loc = 11, column = "Arenas Capacity Rate", value = percentage_arenas)

# %% [markdown]
# - Monaco is in the top of Capacity Rate

# %%
season_2021_2022.sort_values("Arenas Capacity Rate", ascending= False)
# Out:
#     Position              Team  Wins  Losses  Attendance  Budget(In Millions)  \
# 6          7            Monaco    15      13        3536                 14.7
# 4          5  Maccabi Tel Aviv    17      11        8429                 18.0
# 13        14             ASVEL     8      20        4237                 15.1
# 5          6      Anadolu Efes    16      12       11876                 25.0
# 0          1         Barcelona    21       7        5174                 43.5
# 1          2        Olympiacos    19       9        7037                 15.0
# 14        15          Zalgiris     8      20        7630                 10.0
# 10        11     Crvena zvezda    12      16        6042                  8.4
# 8          9          Baskonia    12      16        6885                 10.0
# 11        12        Fenerbahce    10      18        5545                 24.0
# 7          8     Bayern Munich    14      14        2673                 21.0
# ...

# %% [markdown]
# > Teams Per Country

# %%
countries_2022 = season_2021_2022.value_counts(['Country'])
countries_2022
# Out:
# Country
# Spain        3
# France       2
# Germany      2
# Greece       2
# Turkey       2
# Israel       1
# Italy        1
# Lithuania    1
# Serbia       1
# dtype: int64

# %% [markdown]
# - Spain has more teams in Euroleague than others

# %%
country_labels = ['Spain', 'Turkey', 'Greece', 'Lithuania', 'Israel', 'Germany', 'Serbia', 'Italy', 'France']
plt.pie(countries_2022, labels = country_labels, shadow = True)
plt.show()

# %% [markdown]
# $$
# Questions
# $$

# %% [markdown]
# >**#Q1:** *Is there a correlation between the team's budget and their ranking in the season?*

# %%
corr21_22 = season_2021_2022.corr()
sns.heatmap(corr21_22, cmap = 'coolwarm', annot = True )
# Out:
# C:\Users\xrist\AppData\Local\Temp\ipykernel_12232\2916185187.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr21_22 = season_2021_2022.corr()
# <AxesSubplot: >

# %% [markdown]
# **Answer #Q1:** From the table we observe that there is a small correlation *(= -0.66)* between the team's budget and their ranking.

# %% [markdown]
# > **Q2:** How did the attendance of the top teams compare to the attendance of the bottom teams?

# %% [markdown]
# - *We will select as top teams the teams that qualified to* **Playoffs**.

# %%
playoffs_teams = season_2021_2022.loc[0:7]
bottom_teams = season_2021_2022.loc[8:14]

# %%
sum_att_playoffs = playoffs_teams['Total Attendance'].sum()
sum_att_bottom = bottom_teams['Total Attendance'].sum()

# %% [markdown]
# *Visualization*

# %% [markdown]
# - We will make a temporary DataFrame that includes the teams and their attendance.

# %%
teams_att = {
    'Teams' : ['Top Teams', 'Bottom Teams'],
    'Sum_att' : [sum_att_playoffs, sum_att_bottom]
}

df_teams_att = pd.DataFrame(teams_att)

# %%
plt.bar(df_teams_att['Teams'], df_teams_att['Sum_att'], color = ['green', 'red'], width = 0.4, edgecolor = 'black')

plt.title('Attendance of Top Teams VS Bottom Teams')
plt.xlabel('Teams')
plt.ylabel('Attendance')
# Out:
# Text(0, 0.5, 'Attendance')

# %% [markdown]
# **Answer #Q2:** Top Teams have more attendance than Bottom Teams.

# %% [markdown]
# >**#Q3:** *Which country had the highest attendance overall?*

# %% [markdown]
# - We will group each country

# %%
country_grouped = season_2021_2022.groupby('Country').sum()
# Out:
# C:\Users\xrist\AppData\Local\Temp\ipykernel_12232\1347501045.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   country_grouped = season_2021_2022.groupby('Country').sum()

# %% [markdown]
# *Visualization*

# %%
colors = ['#1F77B4', 'black', '#ADD8E6', 'white', 'green', 'yellow', 'blue', 'orange', 'red']

# %%
plt.figure(figsize = (12,6))
plt.bar(country_grouped.index, country_grouped['Total Attendance'], color = colors, edgecolor = 'black')

plt.title('Attendance Per Country')
plt.xlabel('Countries')

plt.ylabel('Total Attendance')
# Out:
# Text(0, 0.5, 'Total Attendance')

# %% [markdown]
# **Answer #Q3:** Throught visualization we notice that *Spain* comes first and *Turkey* second.

# %% [markdown]
# >**#Q4:** *What is the distribution of wins and losses across all the teams?*

# %% [markdown]
# *Visualization*

# %%
temp_df = season_2021_2022[['Team', 'Wins', 'Losses']]
temp_df
# Out:
#                 Team  Wins  Losses
# 0          Barcelona    21       7
# 1         Olympiacos    19       9
# 2       Armani Milan    19       9
# 3        Real Madrid    18      10
# 4   Maccabi Tel Aviv    17      11
# 5       Anadolu Efes    16      12
# 6             Monaco    15      13
# 7      Bayern Munich    14      14
# 8           Baskonia    12      16
# 9        ALBA Berlin    12      16
# 10     Crvena zvezda    12      16
# 11        Fenerbahce    10      18
# 12     Panathinaikos     9      19
# 13             ASVEL     8      20
# 14          Zalgiris     8      20

# %%
temp_df.plot(kind = 'bar', stacked =True, title = 'Wins/Losses Per Team', color = ['green', 'red'])
# Out:
# <AxesSubplot: title={'center': 'Wins/Losses Per Team'}>

# %% [markdown]
# #### **Panathinaikos Analyze**

# %% [markdown]
# >We are going to focus about *Panathinaikos* Wins through years.

# %% [markdown]
# - Season 2016-2017

# %%
wins2016_2017 = season_2016_2017.at[3, 'Wins']
attendance2016_2017 = season_2016_2017.at[3, 'Attendance']
print('Panathinaikos had {} wins in season {} - {}.'.format(wins2016_2017, 2016, 2017))
# Out:
# Panathinaikos had 19 wins in season 2016 - 2017.

# %% [markdown]
# - Season 2017-2018

# %%
wins2017_2018 = season_2017_2018.at[4, 'Wins']
attendance2017_2018 = season_2017_2018.at[4, 'Attendance']
print('Panathinaikos had {} wins in season {} - {}.'.format(wins2017_2018, 2017, 2018))
# Out:
# Panathinaikos had 19 wins in season 2017 - 2018.

# %% [markdown]
# - Season 2018-2019

# %%
wins2018_2019 = season_2018_2019.at[6, 'Wins']
attendance2018_2019 = season_2018_2019.at[6, 'Attendance']
print('Panathinaikos had {} wins in season {} - {}.'.format(wins2018_2019, 2018, 2019))
# Out:
# Panathinaikos had 15 wins in season 2018 - 2019.

# %% [markdown]
# - Season 2020-2021

# %%
wins2020_2021 = season_2020_2021.at[15, 'Wins']
attendance2020_2021 = season_2020_2021.at[15, 'Attendance']
print('Panathinaikos had {} wins in season {} - {}.'.format(wins2020_2021, 2020, 2021))
# Out:
# Panathinaikos had 11 wins in season 2020 - 2021.

# %% [markdown]
# - Season 2021-2022

# %%
wins2021_2022 = season_2021_2022.at[12, 'Wins']
attendance2021_2022 = int(season_2021_2022.at[12, 'Attendance'])
print('Panathinaikos had {} wins in season {} - {}.'.format(wins2021_2022, 2021, 2022))
# Out:
# Panathinaikos had 9 wins in season 2021 - 2022.

# %% [markdown]
# - We make a temporary DataFrame about **Panathinaikos** including *Wins, Attendance, Year*.

# %%
Pana_wins = {
    "Wins" : [wins2016_2017, wins2017_2018, wins2018_2019, wins2020_2021, wins2021_2022],
    "Attendance" : [attendance2016_2017, attendance2017_2018, attendance2018_2019, attendance2020_2021, attendance2021_2022],
    "Year" : ["2016-2017", "2017-2018", "2018-2019", "2020-2021", "2021-2022"]
}

# %%
pana_df = pd.DataFrame(Pana_wins)

# %% [markdown]
# - I mistake input 2020-2021 season so I should delete it because it was Covid-19

# %%
pana_df = pana_df.drop(3)

# %%
pana_df.at[0, 'Attendance'] = 11.172
pana_df.at[1, 'Attendance'] = 10.030
pana_df.at[2, 'Attendance'] = 11.351
pana_df.at[4, 'Attendance'] = 3.883

# %%
pana_df
# Out:
#    Wins  Attendance       Year
# 0    19      11.172  2016-2017
# 1    19      10.030  2017-2018
# 2    15      11.351  2018-2019
# 4     9       3.883  2021-2022

# %% [markdown]
# > We will visualize the effect of bad seasons that Panathinaikos is having these years and the drop of the attendance

# %% [markdown]
# *Visualization*

# %%
plt.figure(figsize = (12,6))
plt.plot(pana_df["Year"], pana_df["Wins"], marker = 'o', c = 'g', label = 'Wins')
plt.plot(pana_df["Year"], pana_df["Attendance"], marker = 'x', c = 'r', label = 'Attendance')
plt.title("Panathinaikos Wins and Attendance Per Year")
plt.xlabel("Year")
plt.ylabel("Wins")
plt.legend()
